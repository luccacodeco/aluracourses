# %% [markdown]
# # Gorjetas

# %% [markdown]
# # Importando Base de dados

# %%
import pandas as pd 
import seaborn as sns

# %%
dados = pd.read_csv('tips.csv')
dados
# Out:
#      total_bill   tip dessert   day    time  size
# 0         16.99  1.01      No   Sun  Dinner     2
# 1         10.34  1.66      No   Sun  Dinner     3
# 2         21.01  3.50      No   Sun  Dinner     3
# 3         23.68  3.31      No   Sun  Dinner     2
# 4         24.59  3.61      No   Sun  Dinner     4
# ..          ...   ...     ...   ...     ...   ...
# 239       29.03  5.92      No   Sat  Dinner     3
# 240       27.18  2.00     Yes   Sat  Dinner     2
# 241       22.67  2.00     Yes   Sat  Dinner     2
# 242       17.82  1.75      No   Sat  Dinner     2
# 243       18.78  3.00      No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %% [markdown]
# # Tradução

# %%
dados.columns
# Out:
# Index(['total_bill', 'tip', 'dessert', 'day', 'time', 'size'], dtype='object')

# %%
renomear = {
    'total_bill': 'valor_da_conta',
    'tip': 'gorjeta', 
    'dessert': 'sobremesa',
    'day': 'dia_da_semana',
    'time': 'hora_do_dia', 
    'size': 'total_de_pessoas'
}

# %%
gorjetas = dados.rename(columns = renomear)

# %%
gorjetas
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0             16.99     1.01        No           Sun      Dinner
# 1             10.34     1.66        No           Sun      Dinner
# 2             21.01     3.50        No           Sun      Dinner
# 3             23.68     3.31        No           Sun      Dinner
# 4             24.59     3.61        No           Sun      Dinner
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92        No           Sat      Dinner
# 240           27.18     2.00       Yes           Sat      Dinner
# 241           22.67     2.00       Yes           Sat      Dinner
# 242           17.82     1.75        No           Sat      Dinner
# 243           18.78     3.00        No          Thur      Dinner
#
#      total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# 239                 3
# 240                 2
# 241                 2
# 242                 2
# 243                 2
#
# [244 rows x 6 columns]

# %%
gorjetas.sobremesa.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sim_nao = {
    'No': 'Não', 
    'Yes': 'Sim'
}

# %%
gorjetas.sobremesa = gorjetas.sobremesa.map(sim_nao)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não           Sun      Dinner
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
dias = {
    'Sun':'Domingo', 
    'Sat':'Sábado',
    'Thur':'Quinta',
    'Fri': 'Sexta'
}

# %%
gorjetas.dia_da_semana = gorjetas.dia_da_semana.map(dias)

# %%
gorjetas.sample(5)
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 104           20.92     4.08       Não        Sábado      Dinner
# 218            7.74     1.44       Sim        Sábado      Dinner
# 27            12.69     2.00       Não        Sábado      Dinner
# 89            21.16     3.00       Não        Quinta       Lunch
# 31            18.35     2.50       Não        Sábado      Dinner
#
#      total_de_pessoas
# 104                 2
# 218                 2
# 27                  2
# 89                  2
# 31                  4

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
hora = {
    'Dinner': 'Jantar',
    'Lunch':'Almoço'
}

# %%
gorjetas.hora_do_dia = gorjetas.hora_do_dia.map(hora)

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Jantar', 'Almoço'], dtype=object)

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4

# %%
# !pip install seaborn==0.9.0
# Out:
# Collecting seaborn==0.9.0
#   Downloading seaborn-0.9.0-py3-none-any.whl (208 kB)
#      -------------------------------------- 208.1/208.1 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=0.14.0 in c:\users\cliente\anaconda3\lib\site-packages (from seaborn==0.9.0) (1.9.1)
# Requirement already satisfied: pandas>=0.15.2 in c:\users\cliente\anaconda3\lib\site-packages (from seaborn==0.9.0) (1.4.4)
# Requirement already satisfied: numpy>=1.9.3 in c:\users\cliente\anaconda3\lib\site-packages (from seaborn==0.9.0) (1.21.5)
# Requirement already satisfied: matplotlib>=1.4.3 in c:\users\cliente\anaconda3\lib\site-packages (from seaborn==0.9.0) (3.5.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cliente\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\cliente\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\cliente\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\cliente\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\cliente\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cliente\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cliente\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cliente\anaconda3\lib\site-packages (from pandas>=0.15.2->seaborn==0.9.0) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\cliente\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->seaborn==0.9.0) (1.16.0)
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
# Successfully installed seaborn-0.9.0

# %%
import seaborn as sns

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.9.0
# Summary: seaborn: statistical data visualization
# Home-page: https://seaborn.pydata.org
# Author: Michael Waskom
# Author-email: mwaskom@nyu.edu
# License: BSD (3-clause)
# Location: c:\users\cliente\anaconda3\lib\site-packages
# Requires: matplotlib, numpy, pandas, scipy
# Required-by:

# %% [markdown]
# # Análise 1 - Valor da conta e gorjeta

# %%
gorjetas.columns
# Out:
# Index(['valor_da_conta', 'gorjeta', 'sobremesa', 'dia_da_semana',
#        'hora_do_dia', 'total_de_pessoas'],
#       dtype='object')

# %%
valor_gorjeta = sns.scatterplot(x='valor_da_conta',y='gorjeta',data=gorjetas)

# %% [markdown]
# # Visualmente, o valor da gorjeta aumenta conforme aumenta o valor da conta.

# %%
print('A base de dados contém {} registros \n'.format(gorjetas.shape[0]))
print('Registros não nulos')
gorjetas.count()
# Out:
# A base de dados contém 244 registros
#
# Registros não nulos
# valor_da_conta      244
# gorjeta             244
# sobremesa           244
# dia_da_semana       244
# hora_do_dia         244
# total_de_pessoas    244
# dtype: int64

# %% [markdown]
# # Criando o campo porcentagem

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas['porcentagem'] = gorjetas.gorjeta/gorjetas.valor_da_conta

# %%
gorjetas.head(5)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2     0.059447
# 1                 3     0.160542
# 2                 3     0.166587
# 3                 2     0.139780
# 4                 4     0.146808

# %%
gorjetas.porcentagem = gorjetas.porcentagem.round(2)

# %%
gorjetas.head(3)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17

# %%
porcentagem_conta = sns.scatterplot(x='valor_da_conta',y='porcentagem', data=gorjetas)

# %% [markdown]
# # Visualmente, o valor da conta não é proporcional ao valor da gorjeta.

# %%
porcentagem_conta_linha = sns.relplot(x='valor_da_conta',y='porcentagem',kind='line',data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', data=gorjetas)

# %%
valor_gorjeta.get_figure()

# %% [markdown]
# # Análise 2 - sobremesa

# %%
gorjetas[gorjetas.sobremesa=='Sim'].describe()
# Out:
#        valor_da_conta    gorjeta  total_de_pessoas  porcentagem
# count       93.000000  93.000000         93.000000    93.000000
# mean        20.756344   3.008710          2.408602     0.163226
# std          9.832154   1.401468          0.810751     0.085060
# min          3.070000   1.000000          1.000000     0.040000
# 25%         13.420000   2.000000          2.000000     0.110000
# 50%         17.920000   3.000000          2.000000     0.150000
# 75%         26.860000   3.680000          3.000000     0.200000
# max         50.810000  10.000000          5.000000     0.710000

# %%
gorjetas[gorjetas.sobremesa=='Não'].describe()
# Out:
#        valor_da_conta     gorjeta  total_de_pessoas  porcentagem
# count      151.000000  151.000000        151.000000   151.000000
# mean        19.188278    2.991854          2.668874     0.159536
# std          8.255582    1.377190          1.017984     0.039889
# min          7.250000    1.000000          1.000000     0.060000
# 25%         13.325000    2.000000          2.000000     0.140000
# 50%         17.590000    2.740000          2.000000     0.160000
# 75%         22.755000    3.505000          3.000000     0.185000
# max         48.330000    9.000000          6.000000     0.290000

# %%
sns.catplot(x='sobremesa',y='gorjeta',data=gorjetas)

# %%
sns.relplot(x='valor_da_conta',y='gorjeta',hue='sobremesa',data=gorjetas)

# %%
sns.relplot(x='valor_da_conta',y='gorjeta',hue='sobremesa',col='sobremesa',data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta',y='gorjeta',hue='sobremesa',col='sobremesa',data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta',y='porcentagem',hue='sobremesa',col='sobremesa',data=gorjetas)

# %% [markdown]
# # Visualmente, existe uma diferença no valor da gorjeta daqueles que pediram sobremesa e os que não pediram

# %%
sns.relplot(x='valor_da_conta',y='porcentagem',hue='sobremesa',col='sobremesa',kind='line',data=gorjetas)

# %% [markdown]
# # Teste de Hipótese

# %% [markdown]
# # H<sup>null</sup>
# # A distribuição da taxa das gorjetas é igual nos dois grupos.
# ## H<sup>alt</sup>
# # A distribuição da taxa das gorjetas não igual nos dois grupos.

# %%
from scipy.stats import ranksums

# %%
sobremesa = gorjetas.query("sobremesa=='Sim'").porcentagem

# %%
sem_sobremesa = gorjetas.query("sobremesa=='Não'").porcentagem

# %%
r = ranksums(sobremesa,sem_sobremesa)

# %%
print('O valor do pvalue é {}'.format(r.pvalue))
# Out:
# O valor do pvalue é 0.5266635660124415

# %% [markdown]
# # H<sup>null</sup>
# # A distribuição da taxa das gorjetas é igual nos dois grupos.

# %% [markdown]
# # Análise 3 - dia da semana

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Domingo', 'Sábado', 'Quinta', 'Sexta'], dtype=object)

# %%
sns.catplot(x='dia_da_semana',y='valor_da_conta',data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana',data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana',data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana',col='dia_da_semana',data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana',col='dia_da_semana',data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana',col='dia_da_semana',data=gorjetas)

# %%
media_geral_gorjetas = gorjetas.gorjeta.mean()

# %%
print('A média geral das gorjetas é de {}'.format(round(media_geral_gorjetas,2)))
# Out:
# A média geral das gorjetas é de 3.0

# %%
gorjetas.groupby(['dia_da_semana']).mean()[['valor_da_conta','gorjeta','porcentagem']]
# Out:
#                valor_da_conta   gorjeta  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132     0.166974
# Quinta              17.682742  2.771452     0.161129
# Sexta               17.151579  2.734737     0.169474
# Sábado              20.441379  2.993103     0.153678

# %%
print('Frequência dos dias')
gorjetas.dia_da_semana.value_counts()
# Out:
# Frequência dos dias
# Sábado     87
# Domingo    76
# Quinta     62
# Sexta      19
# Name: dia_da_semana, dtype: int64

# %% [markdown]
# # Teste de hipótese
# # H<sup>null</sup>
# # A Distribuição do valor da conta é igual no sábado e no domingo
# # Teste de hipótese
# # H<sup>alt</sup>
# # A Distribuição do valor da conta não igual no sábado e no domingo

# %%
valor_conta_domingo = gorjetas.query("dia_da_semana=='Domingo'")['valor_da_conta']

# %%
valor_conta_sabado = gorjetas.query("dia_da_semana=='Sábado'")['valor_da_conta']

# %%
r2 = ranksums(valor_conta_domingo,valor_conta_sabado)

# %%
print('O valor do p-value é {}'.format(r2.pvalue))
# Out:
# O valor do p-value é 0.3576728477868443

# %% [markdown]
# # H<sup>null</sup>
# # A Distribuição do valor da conta é igual no sábado e no domingo

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Jantar', 'Almoço'], dtype=object)

# %% [markdown]
# # Análise 4 - hora do dia

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta', data = gorjetas)

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta', kind='swarm',data = gorjetas)

# %%
sns.violinplot(x='hora_do_dia', y='valor_da_conta', data = gorjetas)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
sns.boxplot(x='hora_do_dia', y = 'valor_da_conta', data = gorjetas)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
almoço = gorjetas.query("hora_do_dia=='Almoço'").valor_da_conta

# %%
jantar = gorjetas.query("hora_do_dia=='Jantar'").valor_da_conta

# %%
sns.histplot(almoço,kde=False)
# Out:
# <AxesSubplot:xlabel='valor_da_conta', ylabel='Count'>

# %%
sns.histplot(jantar)
# Out:
# <AxesSubplot:xlabel='valor_da_conta', ylabel='Count'>

# %%
gorjetas.groupby(['hora_do_dia']).mean()[['valor_da_conta','gorjeta','porcentagem']]
# Out:
#              valor_da_conta   gorjeta  porcentagem
# hora_do_dia
# Almoço            17.168676  2.728088     0.163971
# Jantar            20.797159  3.102670     0.159773

# %% [markdown]
# # Teste de Hipótese
# # Hnull
# # A Distribuição do valor da conta é igual no jantar e no almoço
# # Teste de hipótese
# # Halt
# # A Distribuição do valor da conta não é igual no jantar e no almoço

# %%
r3 = ranksums(jantar,almoço)

# %%
print('O valor do p-value é de {}'.format(r3.pvalue))
# Out:
# O valor do p-value é de 0.0011791039723641672

# %% [markdown]
# # A distribuição do valor da conta não é igual no jantar e no almoço
# # H<sup>alt</sup>

# %%
gorjetas.query("hora_do_dia=='Almoço'").porcentagem
# Out:
# 77     0.15
# 78     0.13
# 79     0.16
# 80     0.15
# 81     0.20
#        ...
# 222    0.22
# 223    0.19
# 224    0.12
# 225    0.15
# 226    0.20
# Name: porcentagem, Length: 68, dtype: float64

# %% [markdown]
# # Teste de Hipótese
# # H<sup>null</sup>
# # A Distribuição da taxa da gorjeta é igual no jantar e no almoço
# # Teste de hipótese
# # H<sup>alt</sup>
# # A Distribuição da taxa da gorjeta não é igual no jantar e no almoço

# %%
porcentagem_almoço = gorjetas.query("hora_do_dia=='Almoço'").porcentagem

# %%
porcentagem_jantar = gorjetas.query("hora_do_dia=='Jantar'").porcentagem

# %%
r4 = ranksums(porcentagem_jantar,porcentagem_almoço)
print('O valor do p-value é de {}'.format(r4.pvalue))
# Out:
# O valor do p-value é de 0.2602493995587126

# %% [markdown]
# # H<sup>null</sup>
# # A distribuição da taxa da gorjeta é igual no almoço e jantar
